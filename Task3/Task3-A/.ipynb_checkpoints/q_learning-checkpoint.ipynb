# %%
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt

# %%
# Create FrozenLake Environment (4x4)

env = gym.make ( "FrozenLake-v1", map_name = "4x4", is_slippery = True )

n_states = env.observation_space.n
n_actions = env.action_space.n

print ( "States:", n_states )
print ( "Actions:", n_actions )
# Out:
# States: 16
# Actions: 4

# %%
# Q-Learning Parameters

alpha = 0.1
gamma = 0.99

epsilon_start = 1.0
epsilon_end = 0.01
episodes = 5000

epsilon_decay = ( epsilon_start - epsilon_end ) / episodes

Q = np.zeros ( ( n_states, n_actions ) )

print ( "Q-table shape:", Q.shape )
# Out:
# Q-table shape: (16, 4)

# %%
rewards_per_episode = []
epsilon = epsilon_start

for episode in range(episodes):
    
    state, _ = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        
        # Epsilon-greedy action selection
        if np.random.random() < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(Q[state])
        
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # Q-learning update
        Q[state, action] = Q[state, action] + alpha * ( reward + gamma * np.max(Q[next_state]) - Q[state, action] )
        
        state = next_state
        total_reward += reward
    
    rewards_per_episode.append ( total_reward )
    
    epsilon = max(epsilon_end, epsilon - epsilon_decay)

print ( "Training complete" )
# Out:
# Training complete

# %%
plt.plot(rewards_per_episode)
plt.title("Rewards per Episode")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.show()

# %%
# Evaluate Learned Policy

test_episodes = 100
success = 0

for _ in range(test_episodes):
    state, _ = env.reset()
    done = False
    
    while not done:
        action = np.argmax(Q[state])
        state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        if reward == 1:
            success += 1

print(f"Success rate over {test_episodes} episodes: {success/test_episodes:.2f}")
# Out:
# Success rate over 100 episodes: 0.78

# %%
# View Final Q-table

print(Q)
# Out:
# [[0.54266786 0.50793862 0.50516734 0.50888909]
#  [0.32825624 0.35635002 0.33989534 0.48913488]
#  [0.41558717 0.38775236 0.37336117 0.46091857]
#  [0.17608093 0.33237099 0.37404537 0.44696066]
#  [0.56986405 0.41302266 0.36593968 0.40905273]
#  [0.         0.         0.         0.        ]
#  [0.25971979 0.20363404 0.22426046 0.12012118]
#  [0.         0.         0.         0.        ]
#  [0.39066036 0.36861817 0.42264875 0.58323928]
#  [0.45743354 0.63894794 0.45987886 0.44365497]
#  [0.65705766 0.37864251 0.30113941 0.29377152]
#  [0.         0.         0.         0.        ]
#  [0.         0.         0.         0.        ]
#  [0.51567322 0.44467524 0.74065257 0.58043653]
#  [0.69991036 0.8627741  0.76059864 0.72493255]
#  [0.         0.         0.         0.        ]]
